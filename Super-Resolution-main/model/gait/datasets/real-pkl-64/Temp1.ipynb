# %%
import pickle
import matplotlib.pyplot as plt

# %%
data = pickle.load(open('probe/b3673079/default/b3673079.pkl', 'rb'))

# %%
data.shape
# Out:
# (267, 64, 64)

# %%
plt.imshow(data[55], cmap='gray')

# %%
data = pickle.load(open('1030/8d91bc15/default/8d91bc15.pkl', 'rb'))

# %%
plt.imshow(data[250], cmap='gray')

# %%
data.shape
# Out:
# (577, 64, 64)
